# %% [markdown]
# # Term Deposit Subscription Prediction
# ### Problem Statement:
# Predict whether a bank customer will subscribe to a term deposit as a result of a direct marketing campaign, based on various customer attributes and historical campaign data.
#
# ### Objective:
# The primary objective is to build and evaluate classification models (e.g., Logistic Regression, Random Forest) to accurately predict term deposit subscriptions. This involves loading and exploring the dataset, preprocessing features, performing exploratory data analysis, training models, evaluating their performance using metrics like Confusion Matrix, F1-Score, ROC Curve, and Accuracy, and gaining insights into customer behavior.

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, f1_score, roc_auc_score, roc_curve

import shap
import warnings
warnings.filterwarnings('ignore')
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# !python -m pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting shap
#   Downloading shap-0.44.1-cp38-cp38-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\program files\python38\lib\site-packages (from shap) (1.24.3)
# Requirement already satisfied: scipy in c:\users\hp\appdata\roaming\python\python38\site-packages (from shap) (1.10.0)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\roaming\python\python38\site-packages (from shap) (1.3.2)
# Requirement already satisfied: pandas in c:\users\hp\appdata\roaming\python\python38\site-packages (from shap) (2.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\program files\python38\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\hp\appdata\roaming\python\python38\site-packages (from shap) (24.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numba in c:\program files\python38\lib\site-packages (from shap) (0.58.1)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: colorama in c:\program files\python38\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\program files\python38\lib\site-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\program files\python38\lib\site-packages (from numba->shap) (8.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python38\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python38\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\roaming\python\python38\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\appdata\roaming\python\python38\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\appdata\roaming\python\python38\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\program files\python38\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in c:\program files\python38\lib\site-packages (from importlib-metadata->numba->shap) (3.20.2)
# Downloading shap-0.44.1-cp38-cp38-win_amd64.whl (450 kB)
# Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: slicer, cloudpickle, shap
# Successfully installed cloudpickle-3.1.1 shap-0.44.1 slicer-0.0.7

# %%
# !python -m pip install numpy==2.2.0 --force-reinstall

# %%
# !python -m pip install matplotlib

# %%
# !python -m pip install seaborn

# %%
# !python -m pip install pandas

# %%
# Step 2: Load and clean the dataset
df = pd.read_csv("data/bank.csv")
print("Top 5 rows of dataset\n")
print(df.head())
print("\nDataset Description\n")
print(df.describe())
# Remove leading/trailing spaces from column names
df.columns = df.columns.str.strip()
# Out:
# Top 5 rows of dataset
#
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   19   oct        79         1     -1         0  unknown  0
# 1  cellular   11   may       220         1    339         4  failure  0
# 2  cellular   16   apr       185         1    330         1  failure  0
# 3   unknown    3   jun       199         4     -1         0  unknown  0
# 4   unknown    5   may       226         1     -1         0  unknown  0
#
# Dataset Description
#
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous            y
# count  4521.000000  4521.000000  4521.000000
# mean     39.766645     0.542579     0.115240
# std     100.121124     1.693562     0.319347
# min      -1.000000     0.000000     0.000000
# 25%      -1.000000     0.000000     0.000000
# 50%      -1.000000     0.000000     0.000000
# 75%      -1.000000     0.000000     0.000000
# max     871.000000    25.000000     1.000000

# %%
# Step 3: Clean and preprocess the target column
print("Unique values before conversion:", df['y'].unique())

# Convert string '0'/'1' to integer 0/1
df['y'] = df['y'].astype(int)

print("Unique values after conversion:", df['y'].unique())
# Out:
# Unique values before conversion: [0 1]
# Unique values after conversion: [0 1]

# %%
# Step 4: Exploratory Data Analysis (EDA)
print("\nTarget class distribution:")
print(df['y'].value_counts(normalize=True))

# Visualize target distribution
sns.countplot(x='y', data=df)
plt.title("Target Class Distribution")
plt.show()

# Correlation heatmap for numeric features
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Target class distribution:
# y
# 0    0.88476
# 1    0.11524
# Name: proportion, dtype: float64

# %%
# Step 5: Preprocessing
# One-hot encode categorical features
df_encoded = pd.get_dummies(df, drop_first=True)

# Separate features and target
X = df_encoded.drop('y', axis=1)
y = df_encoded['y']

# %%
# Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# %%
# Step 7 Feature Scaling with column names preserved
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
# Step 8: Model Training

# Logistic Regression
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train_scaled, y_train)

# Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)  # Trees don't need scaling
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import f1_score, roc_auc_score, classification_report, confusion_matrix, roc_curve
import seaborn as sns
import matplotlib.pyplot as plt

# Predictions and probabilities
log_preds = log_model.predict(X_test_scaled)
log_proba = log_model.predict_proba(X_test_scaled)[:, 1]

# Evaluation metrics
print("\n--- Logistic Regression Evaluation ---")
print("F1 Score:", f1_score(y_test, log_preds))
print("ROC AUC Score:", roc_auc_score(y_test, log_proba))
print("Classification Report:\n", classification_report(y_test, log_preds))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, log_preds), annot=True, fmt='d', cmap="YlGnBu")
plt.title("Logistic Regression - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
fpr_log, tpr_log, _ = roc_curve(y_test, log_proba)
plt.plot(fpr_log, tpr_log, label=f"Logistic Regression AUC = {roc_auc_score(y_test, log_proba):.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve - Logistic Regression")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# --- Logistic Regression Evaluation ---
# F1 Score: 0.38749999999999996
# ROC AUC Score: 0.8904854508787092
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       801
#            1       0.55      0.30      0.39       104
#
#     accuracy                           0.89       905
#    macro avg       0.73      0.63      0.66       905
# weighted avg       0.87      0.89      0.88       905

# %%
# Predictions and probabilities
rf_preds = rf_model.predict(X_test)
rf_proba = rf_model.predict_proba(X_test)[:, 1]

# Evaluation metrics
print("\n--- Random Forest Evaluation ---")
print("F1 Score:", f1_score(y_test, rf_preds))
print("ROC AUC Score:", roc_auc_score(y_test, rf_proba))
print("Classification Report:\n", classification_report(y_test, rf_preds))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, rf_preds), annot=True, fmt='d', cmap="YlGnBu")
plt.title("Random Forest - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_proba)
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest AUC = {roc_auc_score(y_test, rf_proba):.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve - Random Forest")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# --- Random Forest Evaluation ---
# F1 Score: 0.33766233766233766
# ROC AUC Score: 0.8889249015653509
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       801
#            1       0.52      0.25      0.34       104
#
#     accuracy                           0.89       905
#    macro avg       0.71      0.61      0.64       905
# weighted avg       0.86      0.89      0.87       905

# %%
import shap

print("\n--- SHAP Explanation: Logistic Regression ---")
# Create SHAP explainer for logistic regression
log_explainer = shap.Explainer(log_model, X_train_scaled, feature_names=X.columns)
log_shap_values = log_explainer(X_test_scaled[:5])

# Plot waterfall plots for first 5 predictions
for i in range(5):
    print(f"Waterfall Plot - Logistic Regression Prediction {i+1}")
    shap.plots.waterfall(log_shap_values[i], max_display=10)
# Out:
# --- SHAP Explanation: Logistic Regression ---
# Waterfall Plot - Logistic Regression Prediction 1
# Waterfall Plot - Logistic Regression Prediction 2
# Waterfall Plot - Logistic Regression Prediction 3
# Waterfall Plot - Logistic Regression Prediction 4
# Waterfall Plot - Logistic Regression Prediction 5

# %%
# Step 10: SHAP Explanation (for 5 predictions)
explainer = shap.Explainer(model, X_train_scaled, feature_names=X.columns)
shap_values = explainer(X_test_scaled[:5])

# Show SHAP summary for 5 predictions
shap.plots.waterfall(shap_values[0], max_display=10)
shap.plots.waterfall(shap_values[1], max_display=10)
shap.plots.waterfall(shap_values[2], max_display=10)
shap.plots.waterfall(shap_values[3], max_display=10)
shap.plots.waterfall(shap_values[4], max_display=10)

# %%
print("\n--- SHAP Explanation: Random Forest ---")
# Create SHAP explainer for random forest
rf_explainer = shap.Explainer(rf_model, X_train, feature_names=X.columns)
rf_shap_values = rf_explainer(X_test[:5])

# Plot waterfall plots for first 5 predictions
for i in range(5):
    print(f"Waterfall Plot - Random Forest Prediction {i+1}")
    shap.plots.waterfall(rf_shap_values[i], max_display=10)
# Out:
# --- SHAP Explanation: Random Forest ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 print("\n--- SHAP Explanation: Random Forest ---")
#       2 # Create SHAP explainer for random forest
# ----> 3 rf_explainer = shap.Explainer(rf_model, X_train, feature_names=X.columns)
#       4 rf_shap_values = rf_explainer(X_test[:5])
#       6 # Plot waterfall plots for first 5 predictions
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shap\explainers\_explainer.py:188, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     186 elif algorithm == "tree":
#     187     self.__class__ = explainers.TreeExplainer
# --> 188     explainers.TreeExplainer.__init__(self, self.model, self.masker, link=self.link, feature_names=self.feature_names, linearize_link=linearize_link, **kwargs)
#     189 elif algorithm == "additive":
#     190     self.__class__ = explainers.AdditiveExplainer
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shap\explainers\_tree.py:175, in TreeExplainer.__init__(self, model, data, model_output, feature_perturbation, feature_names, approximate, **deprecated_options)
#     173 self.feature_perturbation = feature_perturbation
#     174 self.expected_value = None
# --> 175 self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     176 self.model_output = model_output
#     177 #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shap\explainers\_tree.py:820, in TreeEnsemble.__init__(self, model, data, data_missing, model_output)
#     818 self.input_dtype = np.float32
#     819 scaling = 1.0 / len(model.estimators_) # output is average of trees
# --> 820 self.trees = [SingleTree(e.tree_, normalize=True, scaling=scaling, data=data, data_missing=data_missing) for e in model.estimators_]
#     821 self.objective = objective_name_map.get(model.criterion, None)
#     822 self.tree_output = "probability"
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shap\explainers\_tree.py:820, in <listcomp>(.0)
#     818 self.input_dtype = np.float32
#     819 scaling = 1.0 / len(model.estimators_) # output is average of trees
# --> 820 self.trees = [SingleTree(e.tree_, normalize=True, scaling=scaling, data=data, data_missing=data_missing) for e in model.estimators_]
#     821 self.objective = objective_name_map.get(model.criterion, None)
#     822 self.tree_output = "probability"
#
# File ~\AppData\Roaming\Python\Python38\site-packages\shap\explainers\_tree.py:1678, in SingleTree.__init__(self, tree, normalize, scaling, data, data_missing)
#    1676 if data is not None and data_missing is not None:
#    1677     self.node_sample_weight.fill(0.0)
# -> 1678     _cext.dense_tree_update_weights(
#    1679         self.children_left, self.children_right, self.children_default, self.features,
#    1680         self.thresholds, self.values, 1, self.node_sample_weight, data, data_missing
#    1681     )
#    1683 # we compute the expectations to make sure they follow the SHAP logic
#    1684 self.max_depth = _cext.compute_expectations(
#    1685     self.children_left, self.children_right, self.node_sample_weight,
#    1686     self.values
#    1687 )
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'

# %%
print(X_train.dtypes)
# Out:
# age                    int64
# balance                int64
# day                    int64
# duration               int64
# campaign               int64
# pdays                  int64
# previous               int64
# job_blue-collar         bool
# job_entrepreneur        bool
# job_housemaid           bool
# job_management          bool
# job_retired             bool
# job_self-employed       bool
# job_services            bool
# job_student             bool
# job_technician          bool
# job_unemployed          bool
# job_unknown             bool
# marital_married         bool
# marital_single          bool
# education_secondary     bool
# education_tertiary      bool
# education_unknown       bool
# default_yes             bool
# housing_yes             bool
# loan_yes                bool
# contact_telephone       bool
# contact_unknown         bool
# month_aug               bool
# month_dec               bool
# month_feb               bool
# month_jan               bool
# month_jul               bool
# month_jun               bool
# month_mar               bool
# month_may               bool
# month_nov               bool
# month_oct               bool
# month_sep               bool
# poutcome_other          bool
# poutcome_success        bool
# poutcome_unknown        bool
# dtype: object

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

print("\n--- SHAP Explanation: Random Forest ---")

# Step 1: Convert bools to int (required for SHAP)
X_train_rf = X_train.astype(int)
X_test_rf = X_test.astype(int)

# Step 2: Use TreeExplainer on the trained Random Forest model
rf_explainer = shap.TreeExplainer(rf_model)

# Step 3: Compute SHAP values for 5 test samples
# This will return a list of arrays: [shap_values_class0, shap_values_class1]
rf_shap_values = rf_explainer.shap_values(X_test_rf[:5])

# Step 4: Extract SHAP values for class 1 (positive class)
rf_shap_values_class1 = rf_shap_values[1]  # index 1 → class 1 shap values

# Step 5: Loop through each instance and plot
for i in range(5):
    print(f"Waterfall Plot - Random Forest Prediction {i+1}")
    shap.plots._waterfall.waterfall_legacy(
        expected_value=rf_explainer.expected_value[1],
        shap_values=rf_shap_values_class1[i],
        features=X_test_rf.iloc[i],
        feature_names=X_test_rf.columns,
        max_display=10
    )
    plt.show()
# Out:
# --- SHAP Explanation: Random Forest ---
# Waterfall Plot - Random Forest Prediction 1
# Waterfall Plot - Random Forest Prediction 2
# Waterfall Plot - Random Forest Prediction 3
# Waterfall Plot - Random Forest Prediction 4
# Waterfall Plot - Random Forest Prediction 5
