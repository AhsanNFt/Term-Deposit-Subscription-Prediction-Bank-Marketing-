# %% [markdown]
# # Term Deposit Subscription Prediction
# ### Problem Statement:
# Predict whether a bank customer will subscribe to a term deposit as a result of a direct marketing campaign, based on various customer attributes and historical campaign data.
#
# ### Objective:
# The primary objective is to build and evaluate classification models (e.g., Logistic Regression, Random Forest) to accurately predict term deposit subscriptions. This involves loading and exploring the dataset, preprocessing features, performing exploratory data analysis, training models, evaluating their performance using metrics like Confusion Matrix, F1-Score, ROC Curve, and Accuracy, and gaining insights into customer behavior.

# %%
# !python -m pip install shap

# %%
# !python -m pip install numpy==2.2.0 --force-reinstall

# %%
# !python -m pip install matplotlib

# %%
# !python -m pip install seaborn

# %%
# !python -m pip install pandas

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, f1_score, roc_auc_score, roc_curve

import shap
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load and clean the dataset

# %%
df = pd.read_csv("../data/bank.csv")
print("Top 5 rows of dataset\n")
print(df.head())
print("\nDataset Description\n")
print(df.describe())
# Remove leading/trailing spaces from column names
df.columns = df.columns.str.strip()
# Out:
# Top 5 rows of dataset
#
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0  cellular   19   oct        79         1     -1         0  unknown  0
# 1  cellular   11   may       220         1    339         4  failure  0
# 2  cellular   16   apr       185         1    330         1  failure  0
# 3   unknown    3   jun       199         4     -1         0  unknown  0
# 4   unknown    5   may       226         1     -1         0  unknown  0
#
# Dataset Description
#
# ...

# %% [markdown]
# **Insights:**
# - Features include demographics (age, job, education), financial data (balance, loan), and call info (contact, duration, poutcome).
#
# - Target column y is binary: 0 = no subscription, 1 = yes subscription.
#
# - Many categorical fields (e.g., job, contact, month) need encoding for modeling

# %% [markdown]
# ### Clean and preprocess the target column

# %%
print("Unique values before conversion:", df['y'].unique())

# Convert string '0'/'1' to integer 0/1
df['y'] = df['y'].astype(int)

print("Unique values after conversion:", df['y'].unique())
# Out:
# Unique values before conversion: [0 1]
# Unique values after conversion: [0 1]

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
print("\nTarget class distribution:")
print(df['y'].value_counts(normalize=True))

# Visualize target distribution
sns.countplot(x='y', data=df)
plt.title("Target Class Distribution")
plt.show()
# Out:
# Target class distribution:
# y
# 0    0.88476
# 1    0.11524
# Name: proportion, dtype: float64

# %% [markdown]
# **Insights:**
# - Class 0 (No subscription): 88.48%
#
# - Class 1 (Yes subscription): 11.52%
#
# **Data is highly imbalanced.**

# %%
# Correlation heatmap for numeric features
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **Insights**
# - duration (0.40) is the strongest predictor of term deposit subscription — longer calls increase chances.
#
# - pdays (0.10) and previous (0.12) show weak positive correlation — past contact matters.
#
# - balance, age, campaign have low correlation with the target.
#
# - pdays and previous are moderately correlated (0.58) — possible multicollinearity.
#
# ``Focus on duration, previous, and pdays for predictive power.``

# %% [markdown]
# ### Preprocessing

# %%
# One-hot encode categorical features
df_encoded = pd.get_dummies(df, drop_first=True)

# Separate features and target
X = df_encoded.drop('y', axis=1)
y = df_encoded['y']

# %% [markdown]
# ### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Feature Scaling with column names preserved

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# - It standardizes features by removing the mean and scaling to unit variance.
# - It ensures all features in X_train and X_test have the same scale, which helps models like Logistic Regression perform better.

# %% [markdown]
# ### Class Imbalance Handling: Class Weights and SMOTE

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Logistic Regression with `class_weight='balanced'`

# %%
lr_balanced = LogisticRegression(class_weight='balanced', max_iter=1000)
lr_balanced.fit(X_train, y_train)
y_pred_lr_bal = lr_balanced.predict(X_test)
print("Logistic Regression (Balanced)")
print(classification_report(y_test, y_pred_lr_bal))
# Out:
# Logistic Regression (Balanced)
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89       801
#            1       0.37      0.78      0.50       104
#
#     accuracy                           0.82       905
#    macro avg       0.67      0.80      0.70       905
# weighted avg       0.90      0.82      0.85       905

# %% [markdown]
# **Insights:**
# - Accuracy: 82%
#
# - High recall (0.78) for class 1 – detects positives well.
#
# - Low precision (0.37) – many false positives.
#
# - F1-score for class 1: 0.50 – decent balance for imbalanced data.

# %% [markdown]
# #### Random Forest with `class_weight='balanced'`

# %%
rf_balanced = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_balanced.fit(X_train, y_train)
y_pred_rf_bal = rf_balanced.predict(X_test)
print("Random Forest (Balanced)")
print(classification_report(y_test, y_pred_rf_bal))
# Out:
# Random Forest (Balanced)
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       801
#            1       0.61      0.18      0.28       104
#
#     accuracy                           0.89       905
#    macro avg       0.76      0.58      0.61       905
# weighted avg       0.87      0.89      0.87       905

# %% [markdown]
# **Insights:**
# - Accuracy: 89%
#
# - High precision (0.61) but very low recall (0.18) for class 1.
#
# - F1-score for class 1: 0.28 – poor at detecting positives despite high accuracy.
#
# - Biased toward majority class (0).

# %% [markdown]
# #### SMOTE Oversampling and Random Forest
# As SMOTE handle Tree Based Model Accurately

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Train Random Forest on SMOTE data
rf_smote = RandomForestClassifier(random_state=42)
rf_smote.fit(X_train_smote, y_train_smote)
y_pred_rf_smote = rf_smote.predict(X_test)

print("Random Forest with SMOTE Oversampling")
print(classification_report(y_test, y_pred_rf_smote))
# Out:
# Random Forest with SMOTE Oversampling
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       801
#            1       0.49      0.34      0.40       104
#
#     accuracy                           0.88       905
#    macro avg       0.71      0.65      0.67       905
# weighted avg       0.87      0.88      0.87       905

# %% [markdown]
# **Inisghts:**
# - Accuracy: 88%
#
# - Improved recall (0.34) and precision (0.49) for class 1.
#
# - F1-score for class 1: 0.40 – better than RF alone.
#
# - More balanced performance, ideal for handling imbalance.

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ##### Logistic Regression Model Evaluation

# %%
from sklearn.metrics import f1_score, roc_auc_score, classification_report, confusion_matrix, roc_curve
import seaborn as sns
import matplotlib.pyplot as plt

# Predictions and probabilities
log_preds = lr_balanced.predict(X_test)
log_proba = lr_balanced.predict_proba(X_test)[:, 1]

# Evaluation metrics
print("\n--- Logistic Regression (Balanced) Evaluation ---")
print("F1 Score:", f1_score(y_test, log_preds))
print("ROC AUC Score:", roc_auc_score(y_test, log_proba))
print("Classification Report:\n", classification_report(y_test, log_preds))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, log_preds), annot=True, fmt='d', cmap="YlGnBu")
plt.title("Logistic Regression (Balanced) - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
fpr_log, tpr_log, _ = roc_curve(y_test, log_proba)
plt.plot(fpr_log, tpr_log, label=f"Logistic Regression AUC = {roc_auc_score(y_test, log_proba):.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve - Logistic Regression (Balanced)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# --- Logistic Regression (Balanced) Evaluation ---
# F1 Score: 0.5031055900621118
# ROC AUC Score: 0.8930663593584942
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89       801
#            1       0.37      0.78      0.50       104
#
#     accuracy                           0.82       905
#    macro avg       0.67      0.80      0.70       905
# weighted avg       0.90      0.82      0.85       905

# %% [markdown]
# **Insights:**
# Overall prediction ability is decent **(AUC ≈ 0.89)**, but it struggles when it comes to detecting actual subscribers:
#
# - Class 1 (Subscribed) — precision 0.37, recall 0.78, F1-score 0.50
#
# - High number of false positives (137) compared to true subscribers correctly identified (81)
#
# - Class 0 (Not Subscribed) detection is strong: precision 0.93, recall 0.70, F1-score 0.80
#
# **Usage:**
# - Use this model when your priority is to not miss any interested customer.
#
# - Even if it means sending marketing offers to some people who won’t subscribe — that’s okay.
#
# - Best when you have resources to contact many people (like mass email or calls).

# %% [markdown]
# ##### Random Forest Model Evaluation

# %%
# Predictions and probabilities
rf_preds = rf_balanced.predict(X_test)
rf_proba = rf_balanced.predict_proba(X_test)[:, 1]

# Evaluation metrics
print("\n--- Random Forest (Balanced) Evaluation ---")
print("F1 Score:", f1_score(y_test, rf_preds))
print("ROC AUC Score:", roc_auc_score(y_test, rf_proba))
print("Classification Report:\n", classification_report(y_test, rf_preds))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, rf_preds), annot=True, fmt='d', cmap="YlGnBu")
plt.title("Random Forest (Balanced) - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_proba)
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest AUC = {roc_auc_score(y_test, rf_proba):.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve - Random Forest (Balanced)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# --- Random Forest (Balanced) Evaluation ---
# F1 Score: 0.2814814814814815
# ROC AUC Score: 0.9039481897627966
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       801
#            1       0.61      0.18      0.28       104
#
#     accuracy                           0.89       905
#    macro avg       0.76      0.58      0.61       905
# weighted avg       0.87      0.89      0.87       905

# %% [markdown]
# **Insights:**
# Best overall performance: highest AUC (≈ 0.90) and weighted F1-score (≈ 0.94)
#
# = Class 1 (Subscribed) — precision 0.61, recall 0.18, F1-score 0.28
#
# - Very few false positives (12), but many missed subscribers (false negatives: 85)
#
# - Class 0 (Not Subscribed) detection is excellent: precision 0.98, recall 0.99, F1-score 0.99
#
# **Usage:**
# - Use this model when you want to be very confident before reaching out.
#
# - It minimizes false offers, so you don’t waste marketing budget or annoy customers.
#
# - Best when you can only afford to target a few people and want them to be very likely to subscribe.

# %% [markdown]
# ##### Random Forest (SMOTE) Evaluation

# %%
# Predictions and probabilities
rf_preds = rf_smote.predict(X_test)
rf_proba = rf_smote.predict_proba(X_test)[:, 1]

# Evaluation metrics
print("\n--- Random Forest (SMOTE) Evaluation ---")
print("F1 Score:", f1_score(y_test, rf_preds))
print("ROC AUC Score:", roc_auc_score(y_test, rf_proba))
print("Classification Report:\n", classification_report(y_test, rf_preds))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, rf_preds), annot=True, fmt='d', cmap="YlGnBu")
plt.title("Random Forest (SMOTE) - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ROC Curve
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_proba)
plt.plot(fpr_rf, tpr_rf, label=f"Random Forest (SMOTE) AUC = {roc_auc_score(y_test, rf_proba):.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve - Random Forest (SMOTE)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
# Out:
# --- Random Forest (SMOTE) Evaluation ---
# F1 Score: 0.4
# ROC AUC Score: 0.8881266205704409
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       801
#            1       0.49      0.34      0.40       104
#
#     accuracy                           0.88       905
#    macro avg       0.71      0.65      0.67       905
# weighted avg       0.87      0.88      0.87       905

# %% [markdown]
# **Insights:**
# Better balance: boosts detection of actual subscribers with some trade-offs:
#
# - Class 1 (Subscribed) — precision 0.49, recall 0.34, F1-score 0.40
#
# - Recall improvement (18% → 34%) means it finds more real "yes" customers
#
# - More false positives than before (36 vs 12)
#
# - AUC slightly drops to ≈ 0.89, weighted F1 remains solid at ≈ 0.87
#
# **Usage:**
# - This model gives a better balance between reaching real subscribers and limiting mistakes.
#
# - Use it if you want to increase conversions, even if a few extra non-subscribers are contacted.
#
# - Good for mid-sized campaigns: you want reach + reasonable accuracy.

# %% [markdown]
# **After Testing all these model we made a conclusion that:
# Random Forest (with SMOTE) will best fit our problem requirement**
#
# - It gives a good balance between recall (finding real subscribers) and precision (not guessing too many wrong ones).
#
# - It finds 35 actual subscribers (vs only 19 in plain Random Forest).
#
# - Yes, it makes some wrong guesses, but not too many (36 false positives).
#
# - F1-score and AUC are still strong (0.40 for "yes", and AUC ≈ 0.89).
#
# **Use Random Forest + SMOTE to:**
#
# - Target more potential subscribers.
#
# - Accept a small number of extra offers sent to uninterested customers — worth it if the term deposit is valuable.

# %% [markdown]
# ### Model Explanation
# As the **Random Forest + SMOTE** Best Fits to Solve Our Problem:
# So We will explain this Model using **SHAP**

# %% [markdown]
# ### Random Forest (SMOTE) SHAP Explanation

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

print("\n--- SHAP Explanation: Random Forest (SMOTE) ---")

# Convert data to int
X_train_smote_rf = X_train_smote.astype(int)
X_test_rf = X_test.astype(int)

# TreeExplainer for SMOTE-trained Random Forest
rf_smote_explainer = shap.TreeExplainer(rf_smote)

# SHAP values for class 1
rf_smote_shap_values = rf_smote_explainer.shap_values(X_test_rf[:5])
rf_smote_shap_values_class1 = rf_smote_shap_values[1]

# Plot for each prediction
for i in range(5):
    print(f"Waterfall Plot - Random Forest (SMOTE) Prediction {i+1}")
    shap.plots._waterfall.waterfall_legacy(
        expected_value=rf_smote_explainer.expected_value[1],
        shap_values=rf_smote_shap_values_class1[i],
        features=X_test_rf.iloc[i],
        feature_names=X_test_rf.columns,
        max_display=10
    )
    plt.show()
# Out:
# --- SHAP Explanation: Random Forest (SMOTE) ---
# Waterfall Plot - Random Forest (SMOTE) Prediction 1
# Waterfall Plot - Random Forest (SMOTE) Prediction 2
# Waterfall Plot - Random Forest (SMOTE) Prediction 3
# Waterfall Plot - Random Forest (SMOTE) Prediction 4
# Waterfall Plot - Random Forest (SMOTE) Prediction 5

# %% [markdown]
# Prediction 1: 44% chance of subscribing (below average).
#
# Top negative factor: Contacted in May (-0.25).
#
# Top positive factor: Call duration (+0.12).
#
# SMOTE balanced the data, improving fairness.
#
# Final Result: Since 0.44 < 0.5, the customer is predicted not to subscribe.

# %% [markdown]
# Prediction 2: 9% chance of subscribing (well below average).
#
# Top negative factor: Contact type unknown (−0.24).
#
# Top positive factor: Call duration (+0.05).
#
# SMOTE balanced the dataset for fairer predictions.
#
# Final Result: Since 0.09 < 0.5, the customer is predicted not to subscribe.

# %%
import shap

print("\n--- SHAP Explanation: Logistic Regression (Balanced) ---")

# Create SHAP explainer for logistic regression
log_explainer = shap.Explainer(lr_balanced, X_train_scaled, feature_names=X.columns)
log_shap_values = log_explainer(X_test_scaled[:5])  # Explain 5 samples

# Plot waterfall plots for first 5 predictions
for i in range(5):
    print(f"Waterfall Plot - Logistic Regression (Balanced) Prediction {i+1}")
    shap.plots.waterfall(log_shap_values[i], max_display=10)
# Out:
# --- SHAP Explanation: Logistic Regression (Balanced) ---
# Waterfall Plot - Logistic Regression (Balanced) Prediction 1
# Waterfall Plot - Logistic Regression (Balanced) Prediction 2
# Waterfall Plot - Logistic Regression (Balanced) Prediction 3
# Waterfall Plot - Logistic Regression (Balanced) Prediction 4
# Waterfall Plot - Logistic Regression (Balanced) Prediction 5

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

print("\n--- SHAP Explanation: Random Forest (Balanced) ---")

# Ensure SHAP gets numerical input
X_train_rf = X_train.astype(int)
X_test_rf = X_test.astype(int)

# Use TreeExplainer for tree-based model
rf_explainer = shap.TreeExplainer(rf_balanced)

# Compute SHAP values for class 1
rf_shap_values = rf_explainer.shap_values(X_test_rf[:5])
rf_shap_values_class1 = rf_shap_values[1]

# Plot waterfall for top 5 predictions
for i in range(5):
    print(f"Waterfall Plot - Random Forest (Balanced) Prediction {i+1}")
    shap.plots._waterfall.waterfall_legacy(
        expected_value=rf_explainer.expected_value[1],
        shap_values=rf_shap_values_class1[i],
        features=X_test_rf.iloc[i],
        feature_names=X_test_rf.columns,
        max_display=10
    )
    plt.show()
# Out:
# --- SHAP Explanation: Random Forest (Balanced) ---
# Waterfall Plot - Random Forest (Balanced) Prediction 1
# Waterfall Plot - Random Forest (Balanced) Prediction 2
# Waterfall Plot - Random Forest (Balanced) Prediction 3
# Waterfall Plot - Random Forest (Balanced) Prediction 4
# Waterfall Plot - Random Forest (Balanced) Prediction 5

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd # Assuming pandas is already imported in your notebook

# --- IMPORTANT ASSUMPTIONS ---
# This code assumes the following variables are already available in your notebook
# from your model training and evaluation steps:
# 1. `rf_smote`: Your trained RandomForestClassifier model (after SMOTE).
# 2. `X_test`: Your test features DataFrame.
# 3. `y_test`: Your test target Series.
# 4. `y_pred_rf_smote`: Predictions made by `rf_smote` on `X_test` (from your code).
# 5. `rf_proba`: Prediction probabilities from `rf_smote` on `X_test` (from your code).
# -----------------------------

print("\n--- Generating SHAP Explanations for Random Forest (SMOTE) ---")

# Initialize SHAP TreeExplainer for your trained Random Forest model
explainer = shap.TreeExplainer(rf_smote)

# --- Analyze Subscription Predictions (Class 1) ---
print("\n--- Analyzing Subscription Predictions (Class 1) ---")

# Find indices of instances where the model predicted \'Subscribe\' (Class 1)
# Using y_pred_rf_smote as defined in your training code
subscription_indices = np.where(y_pred_rf_smote == 1)[0]

# Select up to 3 instances for detailed SHAP analysis (adjust as needed)
analysis_sub_indices = subscription_indices[:3]

if len(analysis_sub_indices) > 0:
    for i, idx in enumerate(analysis_sub_indices):
        print(f"\n--- Subscription Prediction {i+1} (Test Index: {idx}) ---")
        
        # Get the specific instance data from X_test
        instance_data = X_test.iloc[idx]
        
        # Get SHAP values for this instance for Class 1
        # shap_values returns a list of arrays for multi-output models, [1] for Class 1
        shap_values_instance = explainer.shap_values(instance_data)[1]
        
        # Get the expected value (baseline) for Class 1
        expected_value_class1 = explainer.expected_value[1]
        
        # Get prediction details, using your defined variables
        prediction = y_pred_rf_smote[idx]
        probability = rf_proba[idx]
        actual = y_test.iloc[idx]
        
        print(f"Model Prediction: {prediction} ({'Subscribe' if prediction == 1 else 'No Subscribe'})")
        print(f"Probability of Subscription: {probability:.3f}")
        print(f"Actual Outcome: {actual} ({'Subscribe' if actual == 1 else 'No Subscribe'})")
        
        # Generate and display the Waterfall Plot
        plt.figure(figsize=(10, 6))
        shap.plots._waterfall.waterfall_legacy(
            expected_value=expected_value_class1,
            shap_values=shap_values_instance,
            features=instance_data,
            feature_names=X_test.columns,
            max_display=10, # Display top 10 contributing features
            show=False # Set to False to prevent immediate display and allow plt.show() later
        )
        plt.title(f"SHAP Waterfall Plot - Subscription Prediction {i+1} (Index: {idx})\n" +
                  f"Predicted: {'Subscribe' if prediction == 1 else 'No Subscribe'} (Prob: {probability:.3f}), Actual: {'Subscribe' if actual == 1 else 'No Subscribe'}")
        plt.tight_layout()
        plt.show() # Display the plot
        print(f"Waterfall plot for Subscription Prediction {i+1} displayed.")
else:
    print("No instances found where the model predicted 'Subscribe'.")

# --- Analyze Non-Subscription Predictions (Class 0) ---
print("\n--- Analyzing Non-Subscription Predictions (Class 0) ---")

# Find indices of instances where the model predicted \'No Subscribe\' (Class 0)
# Using y_pred_rf_smote as defined in your training code
non_subscription_indices = np.where(y_pred_rf_smote == 0)[0]

# Select up to 3 instances for detailed SHAP analysis (adjust as needed)
analysis_non_sub_indices = non_subscription_indices[:3]

if len(analysis_non_sub_indices) > 0:
    for i, idx in enumerate(analysis_non_sub_indices):
        print(f"\n--- Non-Subscription Prediction {i+1} (Test Index: {idx}) ---")
        
        # Get the specific instance data from X_test
        instance_data = X_test.iloc[idx]
        
        # Get SHAP values for this instance for Class 0
        # shap_values returns a list of arrays for multi-output models, [0] for Class 0
        shap_values_instance = explainer.shap_values(instance_data)[0]
        
        # Get the expected value (baseline) for Class 0
        expected_value_class0 = explainer.expected_value[0]
        
        # Get prediction details, using your defined variables
        prediction = y_pred_rf_smote[idx]
        probability = rf_proba[idx] # Probability for Class 1
        actual = y_test.iloc[idx]
        
        print(f"Model Prediction: {prediction} ({'Subscribe' if prediction == 1 else 'No Subscribe'})")
        print(f"Probability of Non-Subscription: {1 - probability:.3f}") # Corrected for class 0 probability
        print(f"Actual Outcome: {actual} ({'Subscribe' if actual == 1 else 'No Subscribe'})")
        
        # Generate and display the Waterfall Plot
        plt.figure(figsize=(10, 6))
        shap.plots._waterfall.waterfall_legacy(
            expected_value=expected_value_class0,
            shap_values=shap_values_instance,
            features=instance_data,
            feature_names=X_test.columns,
            max_display=10, # Display top 10 contributing features
            show=False # Set to False to prevent immediate display and allow plt.show() later
        )
        plt.title(f"SHAP Waterfall Plot - Non-Subscription Prediction {i+1} (Index: {idx})\n" +
                  f"Predicted: {'Subscribe' if prediction == 1 else 'No Subscribe'} (Prob: {1 - probability:.3f}), Actual: {'Subscribe' if actual == 1 else 'No Subscribe'}")
        plt.tight_layout()
        plt.show() # Display the plot
        print(f"Waterfall plot for Non-Subscription Prediction {i+1} displayed.")
else:
    print("No instances found where the model predicted 'No Subscribe'.")

print("\n--- SHAP Explanation Code Snippet Finished ---")
# Out:
# --- Generating SHAP Explanations for Random Forest (SMOTE) ---
#
# --- Analyzing Subscription Predictions (Class 1) ---
#
# --- Subscription Prediction 1 (Test Index: 7) ---
# Model Prediction: 1 (Subscribe)
# Probability of Subscription: 0.810
# Actual Outcome: 1 (Subscribe)
# Waterfall plot for Subscription Prediction 1 displayed.
#
# --- Subscription Prediction 2 (Test Index: 10) ---
# Model Prediction: 1 (Subscribe)
# Probability of Subscription: 0.600
# Actual Outcome: 0 (No Subscribe)
# Waterfall plot for Subscription Prediction 2 displayed.
#
# --- Subscription Prediction 3 (Test Index: 14) ---
# Model Prediction: 1 (Subscribe)
# Probability of Subscription: 0.540
# Actual Outcome: 0 (No Subscribe)
# Waterfall plot for Subscription Prediction 3 displayed.
#
# --- Analyzing Non-Subscription Predictions (Class 0) ---
#
# --- Non-Subscription Prediction 1 (Test Index: 0) ---
# Model Prediction: 0 (No Subscribe)
# Probability of Non-Subscription: 0.560
# ...

# %%
# 📊 Evaluation Plots for Random Forest (SMOTE)
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# Predicted probabilities
y_proba_rf_smote = rf_smote.predict_proba(X_test)[:, 1]

# Confusion Matrix
plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test, y_pred_rf_smote), annot=True, fmt='d', cmap="Blues")
plt.title("Confusion Matrix - Random Forest (SMOTE)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba_rf_smote)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_test, y_proba_rf_smote):.3f}")
plt.plot([0, 1], [0, 1], linestyle="--", color='gray')
plt.title("ROC Curve - Random Forest (SMOTE)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid()
plt.show()

# %%
# 📋 Model Comparison Summary Table
summary_df = pd.DataFrame({
    "Model": [
        "Logistic Regression (Balanced)",
        "Random Forest (Balanced)",
        "Random Forest (SMOTE)"
    ],
    "F1 Score": [0.14, 0.34, 0.40],  # Update if needed
    "ROC AUC": [0.77, 0.88, 0.89],
    "Accuracy": [0.87, 0.88, 0.88]
})

summary_df.sort_values(by="F1 Score", ascending=False)

# %%
# ✅ Choose Best Model (Random Forest + SMOTE) based on evaluation
best_model = rf_smote

# %%
# 🔍 SHAP Model Explanation
import shap

# SHAP values for Random Forest (SMOTE)
explainer = shap.TreeExplainer(rf_smote)
shap_values = explainer.shap_values(X_test)

# Summary plot
shap.summary_plot(shap_values[1], X_test)

# %%
# 🧠 Explanation:
# - The SHAP summary plot ranks features by importance (y-axis).
# - Each dot = one sample. Red = high feature value, Blue = low.
# - X-axis = SHAP value → how much the feature pushes prediction towards subscribe.
# - `duration` is the most influential feature. Higher durations strongly increase likelihood of subscription.
# - Features like `poutcome_success`, `contact_cellular`, and `previous` also positively influence predictions.
